# %% [markdown]
# > This is a self-correcting activity generated by [nbgrader](https://nbgrader.readthedocs.io). Fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Run subsequent cells to check your code.

# %% [markdown]
# ---

# %% [markdown]
# # Machine Learning course assessment 2020

# %% [markdown]
# ## Part 1: questions

# %% [markdown]
# ### Question 1.1
#
# Suppose you want to classify pictures as indoor/outdoor and day/night. Should you use two Logistic Regression classifier or one Softmax Regression classifier? Why?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Question 1.2
#
# Is a Decision Tree node's Gini impurity
# - always lower
# - generally lower
# - generaller higher
# - always higher
#
# than its parent's? Justify your answer.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Question 1.3
#
# Consider a neural network composed of 8 neurons on its input layer, 12 neurons on one hidden layer and 5 neurons on its output layer.
#
# 1. Give the output shapes of its layers.
# 1. What is its total number of parameters (weights)?
#
# Justify your answers.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Question 1.4
#
# Comment the following picture.
#
# ![](images/image1.png)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Question 1.5
#
# Why are interpretability and explainability needed in AI? Give an example to justify your answer.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Part 2: exercise
#
# The goal of this exercise is to train and evaluate several models on the [UCI Adult dataset](https://archive.ics.uci.edu/ml/datasets/Adult).
#
# To reach this goal, you may add new cells, edit or delete existing ones.

# %%
import platform

print(f"Python version: {platform.python_version()}")
assert platform.python_version_tuple() >= ("3", "6")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Setup plots
# %matplotlib inline
plt.rcParams["figure.figsize"] = 10, 8
# %config InlineBackend.figure_format = "retina"
sns.set()

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
def plot_loss_acc(history):
    """Plot training and (optionally) validation loss and accuracy
    Takes a Keras History object as parameter"""

    loss = history.history["loss"]
    epochs = range(1, len(loss) + 1)

    plt.figure(figsize=(10, 10))

    plt.subplot(2, 1, 1)
    plt.plot(epochs, loss, ".--", label="Training loss")
    final_loss = loss[-1]
    title = "Training loss: {:.4f}".format(final_loss)
    plt.ylabel("Loss")
    if "val_loss" in history.history:
        val_loss = history.history["val_loss"]
        plt.plot(epochs, val_loss, "o-", label="Validation loss")
        final_val_loss = val_loss[-1]
        title += ", Validation loss: {:.4f}".format(final_val_loss)
    plt.title(title)
    plt.legend()

    acc = history.history["accuracy"]

    plt.subplot(2, 1, 2)
    plt.plot(epochs, acc, ".--", label="Training acc")
    final_acc = acc[-1]
    title = "Training accuracy: {:.2f}%".format(final_acc * 100)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    if "val_accuracy" in history.history:
        val_acc = history.history["val_accuracy"]
        plt.plot(epochs, val_acc, "o-", label="Validation acc")
        final_val_acc = val_acc[-1]
        title += ", Validation accuracy: {:.2f}%".format(final_val_acc * 100)
    plt.title(title)
    plt.legend()

# %% [markdown]
# ### Data loading

# %%
# Load dataset
df_adult = pd.read_csv("adult.data.csv")
df_adult.shape

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Question 2.1: data preprocessing
#
# What preprocessing steps are necessary here? Justify your answer.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# The following code might be useful:
#
# ```python
# df_adult["target"] = (df_adult["salary"] == ">50K").astype(int)
# ```

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Model training and tuning

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Question 2.2: model evaluation
#
# Justify your choice of metric(s) for evaluation.

# %% [markdown]
# YOUR ANSWER HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Question 2.3: model choice
#
# Analyse the results of the evaluation step and choose the most promising model.

# %% [markdown]
# YOUR ANSWER HERE
